# %%
import pandas as pd

# %%
crit = pd.read_csv(r"C:\Users\singe\660project\data\total data\LIWC-22 Results - crit_liwc - LIWC Analysis.csv")
crit
# Out:
#                                                       A  Analytic  Clout    i  \
# 0     The filmmaking and plotting may not live up to...     89.52   1.48  0.0
# 1     Ant-Man And The Wasp is an ideal popcorn flick...     78.71  58.11  0.0
# 2     It keeps the tone very light and funny, incorp...     72.44  85.50  0.0
# 3     Amid all the fun and action of Ant-Man and the...     97.37  17.46  0.0
# 4          This sequel is much more more fleet of foot.     66.04  40.06  0.0
# ...                                                 ...       ...    ...  ...
# 2694  The irreverence of the original we can say rem...     94.68   4.61  0.0
# 2695  The Guardians of the Galaxy have returned in G...     99.00  40.06  0.0
# 2696  So just when the familial schmaltz threatens t...     47.48  40.06  0.0
# 2697  Guardians of the Galaxy 2 is obviously a hell ...     99.00   7.93  0.0
# 2698  At times, there's a bit too much going on, and...     27.51  77.41  0.0
#
# ...

# %%
aud = pd.read_csv(r"C:\Users\singe\660project\data\total data\LIWC-22 Results - aud_liwc - LIWC Analysis.csv")
aud
# Out:
#                                                       A Analytic  Clout  \
# 0                                                review    89.52  40.06
# 1     Major missed opportunity not getting Rick Mora...    69.92  23.05
# 2                         I really liked it and idk why        1      1
# 3     This is a fun heist movie that is non-stop hil...    82.63  18.97
# 4     not funny or even decent but the action is ser...    10.19      1
# ...                                                 ...      ...    ...
# 4839  2 points for Scarlett Johansson, the film is u...    89.52   1.71
# 4840   An actual good movie, one of the top in the MCU.       99  40.06
# 4841  This movie was great love the sound track for ...    81.45  40.06
# 4842  Captain America: The Winter Soldier surpasses ...    80.69   7.93
# 4843  My God. What a movie. Everything that I hated ...    70.33  16.63
#
#           i   conj  BigWords   prep  Cognition    WPS
# ...

# %%
crit.describe()
# Out:
#           Analytic        Clout            i         conj     BigWords  \
# count  2699.000000  2699.000000  2699.000000  2699.000000  2699.000000
# mean     69.445498    39.296573     0.654387     6.531249    23.108840
# std      31.364044    29.585156     2.337279     5.100863    11.974539
# min       1.000000     1.000000     0.000000     0.000000     0.000000
# 25%      47.930000    12.770000     0.000000     3.130000    15.380000
# 50%      82.280000    40.060000     0.000000     6.250000    22.220000
# 75%      96.210000    59.900000     0.000000     9.520000    29.410000
# max      99.000000    99.000000    27.780000    33.330000   100.000000
#
#               prep    Cognition          WPS
# count  2699.000000  2699.000000  2699.000000
# mean     12.493235    10.887425    18.771860
# std       6.144006     7.864424     8.890931
# min       0.000000     0.000000     1.000000
# 25%       8.700000     5.260000    12.000000
# 50%      12.500000    10.000000    17.000000
# ...

# %%
aud.describe()
# Out:
#                  i         conj     BigWords         prep    Cognition  \
# count  4843.000000  4843.000000  4843.000000  4843.000000  4843.000000
# mean      2.245121     6.576102    17.324613    10.088980    12.422333
# std       3.974191     5.512868    11.168299     6.297416     8.857959
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     1.225000    11.110000     6.250000     6.670000
# 50%       0.000000     6.450000    16.670000    10.530000    12.000000
# 75%       3.330000     9.380000    22.220000    14.290000    16.770000
# max      68.940000    37.500000   100.000000    40.000000   100.000000
#
#                WPS
# count  4843.000000
# mean     14.843649
# std      11.598796
# min       0.000000
# 25%       8.000000
# 50%      12.330000
# 75%      18.120000
# max     189.000000
